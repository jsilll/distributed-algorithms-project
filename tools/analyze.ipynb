# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Perfect Links Memory Usage Analysis

# %%
df_pl = pd.read_csv('pl.csv')
df_pl.plot(subplots=True)
plt.show()

# %% [markdown]
# # Uniform Reliable Broadcast Memory Usage Analysis

# %%
df_urb = pd.read_csv('urb.csv')
df_urb.plot(subplots=True)
plt.show()

# %%
df_urb['own_pending_for_broadcast_'][15:40].plot()
# Out:
# <AxesSubplot:>

# %%
df_urb['delivered_'][300:350].plot()
# Out:
# <AxesSubplot:>

# %%
df_urb['acks_'][0:300].plot()
# Out:
# <AxesSubplot:>

# %%
df_urb = pd.read_csv('urb_v2.csv')
df_urb.plot(subplots=True, figsize=(8,8))
plt.show()

# %%
df_urb = pd.read_csv('urb_v3.csv')
df_urb.plot(subplots=True, figsize=(8,8))
plt.show()
